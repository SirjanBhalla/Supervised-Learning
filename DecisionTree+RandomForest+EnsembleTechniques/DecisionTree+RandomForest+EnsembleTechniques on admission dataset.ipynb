# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('admission.csv')
data.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data = data.drop(['Serial No.'], axis=1)

# %%
data.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
data.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000         500.00000
# mean     8.576440    0.560000           0.72174
# std      0.604813    0.496884           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %% [markdown]
# ### All of the data is of numerical type

# %% [markdown]
# # Answer_1: EDA

# %% [markdown]
# #### a) Visualizing 10 random rows:

# %%
import random

res = [random.randrange(1, 500, 1) for i in range(10)]
 

print ("Random numbers are : " +  str(res))
# Out:
# Random numbers are : [410, 144, 178, 260, 406, 195, 324, 243, 256, 491]

# %%
data_ten= data.iloc[res]

# %%
data_ten
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 410        301           96                  1  3.0   4.0  7.56         0
# 144        325          112                  2  3.0   3.5  8.96         1
# 178        309          108                  3  2.5   3.0  8.12         0
# 260        327          108                  5  5.0   3.5  9.13         1
# 406        322          103                  4  3.0   2.5  8.02         1
# 195        307          107                  2  3.0   3.5  8.52         1
# 324        315          104                  3  3.0   2.5  8.33         0
# 243        325          114                  3  3.5   3.0  9.04         1
# 256        309           99                  3  4.0   4.0  8.56         0
# 491        297           99                  4  3.0   3.5  7.81         0
#
#      Chance of Admit
# 410              0.54
# 144              0.80
# 178              0.72
# 260              0.87
# 406              0.61
# ...

# %%
sns.pairplot(data_ten, kind='reg')

# %% [markdown]
# #### b)

# %%
for col in data.columns:
    sns.distplot(data[col], kde=True, hist=True)
    
    plt.show()

# %%
data.hist(figsize = (10,10));

# %%
sns.regplot(x="GRE Score", y="TOEFL Score", data=data)
plt.title("GRE Score vs TOEFL Score")
plt.show()

# %% [markdown]
# #### People with higher GRE Scores also have higher TOEFL Scores

# %%
sns.regplot(x="GRE Score", y="CGPA", data=data)
plt.title("GRE Score vs CGPA")
plt.show()

# %% [markdown]
# #### people with higher CGPA show to have higher GRE scores

# %%
sns.regplot(x="CGPA", y="SOP", data=data)
plt.title("CGPA vs SOP")
plt.show()

# %% [markdown]
# #### there is no relation between SOP and CGPA

# %%
sns.regplot(x="CGPA", y="TOEFL Score", data=data)
plt.title("CGPA vs TOEFL")
plt.show()

# %% [markdown]
# #### people with higher CGPA show to have higher TOEFL score

# %%
sns.scatterplot(y='University Rating',x='CGPA',data=data,color='Green')

# %% [markdown]
# #### increase in cgpa shows an increase in the university rating

# %%
data.Research.value_counts()
# Out:
# 1    280
# 0    220
# Name: Research, dtype: int64

# %% [markdown]
# #### c)

# %%
print("The shape of the data is:",data.shape)
# Out:
# The shape of the data is: (500, 8)

# %% [markdown]
# #### d)

# %%
print("The correlation matrix is: \n\n")
data.corr()
# Out:
# The correlation matrix is:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.827200           0.635376  0.613498
# TOEFL Score         0.827200     1.000000           0.649799  0.644410
# University Rating   0.635376     0.649799           1.000000  0.728024
# SOP                 0.613498     0.644410           0.728024  1.000000
# LOR                 0.524679     0.541563           0.608651  0.663707
# CGPA                0.825878     0.810574           0.705254  0.712154
# Research            0.563398     0.467012           0.427047  0.408116
# Chance of Admit     0.810351     0.792228           0.690132  0.684137
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.524679  0.825878  0.563398          0.810351
# TOEFL Score        0.541563  0.810574  0.467012          0.792228
# University Rating  0.608651  0.705254  0.427047          0.690132
# ...

# %% [markdown]
# #### e)

# %%
sns.pairplot(data=data)

# %% [markdown]
# #### All variables show good correlation to each other

# %% [markdown]
# # Answer_2: Min and Max value of GRE score

# %%
print("Min value of GRE score:",min(data['GRE Score']))
# Out:
# Min value of GRE score: 290

# %%
print("Max value of GRE score:",max(data['GRE Score']))
# Out:
# Max value of GRE score: 340

# %% [markdown]
# # Answer_3: Percentage of universities for each university rating

# %%
data['University Rating'].value_counts()
# Out:
# 3    162
# 2    126
# 4    105
# 5     73
# 1     34
# Name: University Rating, dtype: int64

# %%
colors = ['purple','orange','pink','gray','green']
explode = [0,0.1,0,0,0]
plt.figure(figsize=(7,7))
plt.pie(data['University Rating'].value_counts().values,explode=explode,labels=data['University Rating'].value_counts().index,colors=colors,autopct='%1.1f%%')
plt.title('University Rating')
plt.show()

# %% [markdown]
# # Answer_4: Converting the target variable “Chance of Admit” to categorical having values 0 and 1

# %%
data['Chance of Admit '] = data['Chance of Admit '].apply(lambda x: 1 if x >=0.80 else 0)

data['Chance of Admit '].value_counts()
# Out:
# 0    345
# 1    155
# Name: Chance of Admit , dtype: int64

# %%
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                   1
# 1                   0
# ...

# %%
X=data.drop('Chance of Admit ',axis=1)
y=data['Chance of Admit ']

# %%
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 495    1
# 496    1
# 497    1
# 498    0
# 499    1
# Name: Chance of Admit , Length: 500, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y ,random_state=14)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def print_score(clf,X_train, X_test, y_train, y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        print("Train result is: \n =============")
        print(f"Accuracy score is: {accuracy_score(y_train,pred)*100}\n")
        print(f"Confusion Matrix is: {confusion_matrix(y_train,pred)}\n")

        
    elif train == False:
        pred = clf.predict(X_test)
        print("Test result is: \n =============")
        print(f"Accuracy score is: {accuracy_score(y_test,pred)*100}\n")
        print(f"Confusion Matrix is: {confusion_matrix(y_test,pred)}\n")

# %%
print('X_train',X_train.shape)
print('X_test',X_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# X_train (375, 7)
# X_test (125, 7)
# y_train (375,)
# y_test (125,)

# %% [markdown]
# # Answer_5: Decision Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
tree= DecisionTreeClassifier(random_state = 14)
tree.fit(X_train,y_train)


print_score(tree, X_train, X_test, y_train, y_test, train = True)
print_score(tree, X_train, X_test, y_train, y_test, train = False)
# Out:
# Train result is:
# ...
# Accuracy score is: 100.0
#
# Confusion Matrix is: [[259   0]
#  [  0 116]]
#
# Test result is:
# ...
# Accuracy score is: 92.80000000000001
#
# Confusion Matrix is: [[79  7]
#  [ 2 37]]

# %% [markdown]
# ### hyperparameter tuning

# %%
from sklearn.tree import DecisionTreeClassifier
tree= DecisionTreeClassifier(random_state = 14,criterion='entropy', max_features= "auto")
tree.fit(X_train,y_train)

print_score(tree, X_train, X_test, y_train, y_test, train = True)
print_score(tree, X_train, X_test, y_train, y_test, train = False)
# Out:
# Train result is:
# ...
# Accuracy score is: 100.0
#
# Confusion Matrix is: [[259   0]
#  [  0 116]]
#
# Test result is:
# ...
# Accuracy score is: 94.39999999999999
#
# Confusion Matrix is: [[80  6]
#  [ 1 38]]

# %% [markdown]
# # Answer_6: Random Forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

random_F_classifier = RandomForestClassifier(n_estimators=200, random_state=14)
random_F_classifier.fit(X_train,y_train)

print_score(random_F_classifier, X_train, X_test, y_train, y_test, train = True)
print_score(random_F_classifier, X_train, X_test, y_train, y_test, train = False)
# Out:
# Train result is:
# ...
# Accuracy score is: 100.0
#
# Confusion Matrix is: [[259   0]
#  [  0 116]]
#
# Test result is:
# ...
# Accuracy score is: 96.0
#
# Confusion Matrix is: [[82  4]
#  [ 1 38]]

# %% [markdown]
# ### hyperparameter tuning

# %%
random_F_classifier_u= RandomForestClassifier(criterion='entropy', max_features='auto', n_estimators=200, random_state=14)
random_F_classifier_u.fit(X_train,y_train)

print_score(random_F_classifier_u, X_train, X_test, y_train, y_test, train = True)
print_score(random_F_classifier_u, X_train, X_test, y_train, y_test, train = False)
# Out:
# Train result is:
# ...
# Accuracy score is: 100.0
#
# Confusion Matrix is: [[259   0]
#  [  0 116]]
#
# Test result is:
# ...
# Accuracy score is: 94.39999999999999
#
# Confusion Matrix is: [[81  5]
#  [ 2 37]]

# %% [markdown]
# # # Answer_7: Ensemble Modelling techniques

# %% [markdown]
# ### Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

bgc=BaggingClassifier(DecisionTreeClassifier(), max_samples= 0.5, max_features=1.0, n_estimators=20, random_state=14)
bgc.fit(X_train,y_train)

print_score(bgc, X_train, X_test, y_train, y_test, train = True)
print_score(bgc, X_train, X_test, y_train, y_test, train = False)
# Out:
# Train result is:
# ...
# Accuracy score is: 96.8
#
# Confusion Matrix is: [[253   6]
#  [  6 110]]
#
# Test result is:
# ...
# Accuracy score is: 96.0
#
# Confusion Matrix is: [[82  4]
#  [ 1 38]]

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier

# %%
gboost_model = GradientBoostingClassifier(random_state=14)
gboost_model.fit(X_train,y_train)

print_score(gboost_model, X_train, X_test, y_train, y_test, train = True)
print_score(gboost_model, X_train, X_test, y_train, y_test, train = False)
# Out:
# Train result is:
# ...
# Accuracy score is: 98.93333333333332
#
# Confusion Matrix is: [[258   1]
#  [  3 113]]
#
# Test result is:
# ...
# Accuracy score is: 92.80000000000001
#
# Confusion Matrix is: [[78  8]
#  [ 1 38]]

# %% [markdown]
# ### Adaboost

# %%
ada_model = AdaBoostClassifier(random_state=14)
ada_model.fit(X_train,y_train)


print_score(ada_model, X_train, X_test, y_train, y_test, train = True)
print_score(ada_model, X_train, X_test, y_train, y_test, train = False)
# Out:
# Train result is:
# ...
# Accuracy score is: 95.73333333333333
#
# Confusion Matrix is: [[252   7]
#  [  9 107]]
#
# Test result is:
# ...
# Accuracy score is: 91.2
#
# Confusion Matrix is: [[79  7]
#  [ 4 35]]

# %% [markdown]
# # Answer_8: Comparison and Conclusion

# %% [markdown]
# ##  `Train data`:
# #### 1)Decision Tree: 100.0%
# #### 2)Decision Tree(Hyperparameter tuning): 100.0%
# #### 3)Random Forest: 100.0%
# #### 4)Random Forest(hyperparameter tuning): 100.0%
# #### 5)Bagging Classifier: 96.8%
# #### 6)Gradient Boosting: 98.93%
# #### 7)Adaboost: 95.73%
#
# ##  `Test data`:
# #### 1)Decision Tree: 92.80%
# #### 2)Decision Tree(Hyperparameter tuning): 94.39%
# #### 3)Random Forest: 96.0%
# #### 4)Random Forest(hyperparameter tuning): 94.39%
# #### 5)Bagging Classifier: 96.0%
# #### 6)Gradient Boosting: 92.80%
# #### 7)Adaboost: 91.2%

# %% [markdown]
# ## After seeing various models and comparing accuracies we get the best accuracy of 96% from Bagging Classifier.
